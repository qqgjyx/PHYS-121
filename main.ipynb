# %%
15 * (19.5 + 19 + 20 +20)/(20 + 20 + 20 +20) + 8 * 16.24 / 20 + 32 * 84.9 /100 + 20 * (61.5 + 85 + 78 + 91 + 86 +106) / (61 + 84 +77 +92 + 106 + 111) + 15 * 40 / 50 + 10
# Out:
# 89.49762758945386
